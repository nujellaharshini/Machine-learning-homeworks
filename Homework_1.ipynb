# %%
! pip install transformers
! pip install diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 11.4 MB/s eta 0:00:00
# ...

# %%
import urllib.request
urllib.request.urlretrieve (
" https://ucmercedcse176.github.io/files/resource/cat.jpeg",
"cat.jpeg ")
# Out:
# ('cat.jpeg ', <http.client.HTTPMessage at 0x7a0b192217b0>)

# %%
# image classification
from transformers import pipeline
clf = pipeline("image-classification")
clf("https://ucmercedcse176.github.io/files/resource/cat.jpeg")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# [{'label': 'tabby, tabby cat', 'score': 0.5493165254592896},
#  {'label': 'Egyptian cat', 'score': 0.2343982756137848},
#  {'label': 'tiger cat', 'score': 0.20650842785835266},
#  {'label': 'lynx, catamount', 'score': 0.003537504468113184},
#  {'label': 'Persian cat', 'score': 0.0006965894717723131}]

# %%
# !pip install diffusers transformers
# !pip install torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 36.0 MB/s eta 0:00:00
# ...

# %%
# visual question answering
from PIL import Image
import requests
from transformers import pipeline

vqa_pipeline = pipeline("visual-question-answering")

url = "https://ucmercedcse176.github.io/files/resource/cat.jpeg"
image = Image.open(requests.get(url, stream=True).raw)
question = "Is there a cat?"

vqa_pipeline(image, question, top_k=1)
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision 4355f59 (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'score': 0.9994431138038635, 'answer': 'yes'}]

# %%
# image to text
from transformers import pipeline

captioner = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
captioner("https://ucmercedcse176.github.io/files/resource/cat.jpeg")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'a cat looking up at the sky'}]

# %%
# text to image
import torch
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler, FluxPipeline

model_id = "stabilityai/stable-diffusion-2"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
# pipe.enable_model_cpu_offload()
pipe = pipe.to("cuda")

prompt = "a photo of an astronaut riding a horse on mars"
image = pipe(prompt).images[0]
image.save("astro.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
